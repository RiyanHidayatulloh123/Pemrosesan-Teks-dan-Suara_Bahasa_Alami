# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
# !pip install PySastrawi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.6/210.6 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# !pip install Sastrawi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Ganti 'namafile.txt' dengan nama file sebenarnya.
file_path = 'pidato_jendral_sudirman.txt'

# Baca file dan cetak isinya
with open(file_path, 'r') as file:
   isi_berita = file.read()
   print(isi_berita)
# Out:
# Assalamu’alaikum wr. wb.
# Merdeka!
#
# Mudah-mudahan Tuhan Yang Maha Murah lagi Maha Asih tetap memberi perlindungan, petunjuk serta kekuatan pada hamba-Nya yang terus-menerus sama melakukan kewajiban, membela serta mempertahankan Kedaulatan dan Kemerdekaan negara Republik Indonesia.
#
# Saudara Pemimpin dan hadirin sekalian yang terhormat.
# Kami, mengucapkan syukur dan gembira dalam saat yang sangat genting-penting ini, pergerakan Islam Muhammadiyah dapat menyelenggarakan pertemuan silaturahim yang sangat penting artinya, dalam suasana perjuangan kemerdekaan yang sangat memuncak ini. Kami percaya dan yakin, bahwa, segala keputusan yang diambil dalam pertemuan selama ini akan sangat besar faedah dan gunanya, untuk menambah dan memperkuat bekal perjuangan kemerdekaan dan selanjutnya langkah serta amalan Muhammadiyah dapat disesuaikan dengan jalannya perjuangan pada dewasa ini.
#
# Saudara-saudara sekalian !
# ...

# %%
word_tokens = word_tokenize(isi_berita)
print(word_tokens)
# Out:
# ['Assalamu', '’', 'alaikum', 'wr', '.', 'wb', '.', 'Merdeka', '!', 'Mudah-mudahan', 'Tuhan', 'Yang', 'Maha', 'Murah', 'lagi', 'Maha', 'Asih', 'tetap', 'memberi', 'perlindungan', ',', 'petunjuk', 'serta', 'kekuatan', 'pada', 'hamba-Nya', 'yang', 'terus-menerus', 'sama', 'melakukan', 'kewajiban', ',', 'membela', 'serta', 'mempertahankan', 'Kedaulatan', 'dan', 'Kemerdekaan', 'negara', 'Republik', 'Indonesia', '.', 'Saudara', 'Pemimpin', 'dan', 'hadirin', 'sekalian', 'yang', 'terhormat', '.', 'Kami', ',', 'mengucapkan', 'syukur', 'dan', 'gembira', 'dalam', 'saat', 'yang', 'sangat', 'genting-penting', 'ini', ',', 'pergerakan', 'Islam', 'Muhammadiyah', 'dapat', 'menyelenggarakan', 'pertemuan', 'silaturahim', 'yang', 'sangat', 'penting', 'artinya', ',', 'dalam', 'suasana', 'perjuangan', 'kemerdekaan', 'yang', 'sangat', 'memuncak', 'ini', '.', 'Kami', 'percaya', 'dan', 'yakin', ',', 'bahwa', ',', 'segala', 'keputusan', 'yang', 'diambil', 'dalam', 'pertemuan', 'selama', 'ini', 'akan', 'sangat
# ...

# %%
stop_words = set(stopwords.words('indonesian'))
word_tokens_no_stopwords = [w for w in word_tokens if not w in stop_words]
print(word_tokens_no_stopwords)
# Out:
# ['Assalamu', '’', 'alaikum', 'wr', '.', 'wb', '.', 'Merdeka', '!', 'Mudah-mudahan', 'Tuhan', 'Yang', 'Maha', 'Murah', 'Maha', 'Asih', 'perlindungan', ',', 'petunjuk', 'kekuatan', 'hamba-Nya', 'terus-menerus', 'kewajiban', ',', 'membela', 'mempertahankan', 'Kedaulatan', 'Kemerdekaan', 'negara', 'Republik', 'Indonesia', '.', 'Saudara', 'Pemimpin', 'hadirin', 'terhormat', '.', 'Kami', ',', 'syukur', 'gembira', 'genting-penting', ',', 'pergerakan', 'Islam', 'Muhammadiyah', 'menyelenggarakan', 'pertemuan', 'silaturahim', ',', 'suasana', 'perjuangan', 'kemerdekaan', 'memuncak', '.', 'Kami', 'percaya', ',', ',', 'keputusan', 'diambil', 'pertemuan', 'faedah', 'gunanya', ',', 'menambah', 'memperkuat', 'bekal', 'perjuangan', 'kemerdekaan', 'langkah', 'amalan', 'Muhammadiyah', 'disesuaikan', 'jalannya', 'perjuangan', 'dewasa', '.', 'Saudara-saudara', '!', 'Suasana', 'politik', 'meliputi', 'negara', 'bangsa', 'menentukan', 'nasib', 'negara', 'Bangsa', 'Indonesia', ',', 'berabad-abad', ',', 'punc
# ...

# %%
freq_kata_1 = nltk.FreqDist(word_tokens)
freq_kata_2 = nltk.FreqDist(word_tokens_no_stopwords)
print(freq_kata_1.most_common(10))
print()
print(freq_kata_2.most_common(10))
# Out:
# [(',', 82), ('dan', 63), ('.', 52), ('yang', 42), ('kita', 27), ('itu', 18), ('Indonesia', 16), ('sekalian', 16), ('di', 16), ('akan', 14)]
#
# [(',', 82), ('.', 52), ('Indonesia', 16), ('!', 12), ('bangsa', 12), ('perjuangan', 11), ('golongan', 11), ('persetujuan', 8), ('naskah', 8), ('imperialis', 7)]

# %%
import matplotlib.pyplot as plt

# %%
freq_kata_1.plot(10)
freq_kata_2.plot(10)
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from collections import Counter

# Baca teks pidato dari file
with open('pidato_jendral_sudirman.txt', 'r', encoding='utf-8') as file:
    pidato = file.read()

# Tokenisasi teks
tokens = word_tokenize(pidato)

# Hapus kata-kata stopwords (kata-kata umum yang tidak memberikan makna khusus)
stop_words = set(stopwords.words('indonesian'))
filtered_tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

# Hitung frekuensi kata-kata
word_freq = Counter(filtered_tokens)

# Ambil 20 kata yang paling sering muncul
common_words = word_freq.most_common(20)

# Siapkan data untuk plot
words, frequencies = zip(*common_words)

# Plot kata-kata yang paling sering muncul
plt.figure(figsize=(12, 6))
plt.bar(words, frequencies)
plt.xlabel('Kata-kata')
plt.ylabel('Frekuensi')
plt.title('10 Kata Paling Sering Muncul dalam Pidato')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
